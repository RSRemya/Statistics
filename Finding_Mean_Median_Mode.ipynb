# %%
data=[23,24,32,45,12,43,67,45,32,56,32]
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy=data.copy()
data_copy.sort()
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data_copy.append(150)
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 150]

# %%
import numpy as np
np.mean(data_copy)
# Out:
# 46.75

# %%
np.median(data_copy)
# Out:
# 37.5

# %%
import seaborn as sns
sns.histplot(data)# To find the mode histplot can be used, because it shows occurance of elements
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(data, kde=True)#used to get smoothened curve
#also it shows distribution of data
#kde --> kernal density function
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
import statistics
statistics.mode(data_copy)
# Out:
# 32
